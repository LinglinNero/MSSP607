# %% [markdown]
# <a href="https://colab.research.google.com/github/LinglinNero/MSSP607/blob/main/PARTICIPATION_ACTIVITY_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#connect to github file
from google.colab import userdata
import os

github_token = userdata.get('Git_Hub')
owner = 'LinglinNero' # Replace with the GitHub repository owner
repository = 'MSSP607' # Replace with the GitHub repository name

clone_url = f'https://{github_token}@github.com/{owner}/{repository}.git'

# Clone the repository
# !git clone {clone_url}

# %%
import pandas as pd
import matplotlib.pyplot as plt


sales = pd.read_csv('/content/drive/MyDrive/MSSP607/Modules/Module7/InternetSales.csv', encoding="latin1")
sales['OrderDateKey'] = pd.to_datetime(sales['OrderDateKey'], format='%Y%m%d')
sales['Year'] = sales['OrderDateKey'].dt.year

yearly_sales = sales.groupby('Year')['SalesAmount'].sum().reset_index()

plt.figure(figsize = (10, 6))
plt.bar(yearly_sales['Year'], yearly_sales['SalesAmount'])
plt.xlabel('Year')
plt.ylabel('Sales Amount')
plt.title('Yearly Sales')
plt.savefig('/content/drive/MyDrive/MSSP607/Modules/Module7/yearly_sales.pdf', format='pdf')
plt.show()
# Out:
# /tmp/ipython-input-2360828419.py:5: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('/content/drive/MyDrive/MSSP607/Modules/Module7/InternetSales.csv', encoding="latin1")
